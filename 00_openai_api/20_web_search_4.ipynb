# %%
import os
from openai import OpenAI
import rich
from google.colab import userdata

# %%
api_key = userdata.get('OPENAI_API_KEY')
MODEL = "gpt-4o-mini"

openai = OpenAI(api_key=api_key)

# %% [markdown]
# Search the web for the latest information before generating a response
#
# 1) In Chat API, model always retrieves information from web before responding to your query
#
# 2) In Responses API, you enable web search by configuring it in the tools, and model can choose to serach the web or not based on the content of the input prompt.

# %% [markdown]
# In the Responses API, if you want to ensure that the model must call the tool, you can use the `tool_choice` parameter and set it to `{type: "web_search_preview"}`. This helps reduce latency and provides more consistent results.
#
# Since the Chat API uses a specific model that always performs a web search, this use case is more relevant to the Responses API.

# %% [markdown]
# # Responses API
#
# https://platform.openai.com/docs/guides/tools-web-search?api-mode=responses

# %%
response = openai.responses.create(
    model=MODEL,
    tools=[{
        "type": "web_search_preview",
        "user_location": {
            "type": "approximate",
            "country": "PK",
            "city": "Lahore",
            "region": "Punjab",
        }
    }],
    # input="List the best restaurants for Seafood",
    input="What is Agentic AI?",
    tool_choice={"type": "web_search_preview"} # Added tool_choice property
)

print(response.output_text)
rich.print(response.output)
rich.print(response.tools)
# rich.print(response)
# Out:
# Agentic AI refers to artificial intelligence systems that possess the capability to act autonomously, make decisions, and pursue objectives without continuous human intervention. Unlike traditional AI, which typically responds to user inputs or predefined instructions, agentic AI can independently analyze its environment, set goals, and execute actions to achieve those goals. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# **Key Characteristics of Agentic AI:**
#
# - **Autonomy:** Agentic AI systems can operate independently, reducing the need for constant human oversight. This autonomy is particularly beneficial in scenarios that require continuous monitoring or rapid decision-making. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Adaptability:** These systems can adjust their behavior in response to changes in their environment, allowing them to handle new or ambiguous information without human guidance. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# - **Problem-Solving:** Agentic AI can engage in planning, reasoning, and goal-setting, enabling them to tackle complex tasks beyond the capabilities of traditional AI. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# - **Collaboration:** Multiple agentic AI systems can work together to address intricate scenarios, such as coordinating efforts in search-and-rescue missions. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# **Potential Applications:**
#
# - **Business Operations:** Agentic AI can manage supply chains, optimize inventory levels, forecast demand, and plan logistics, leading to increased efficiency and cost savings. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Healthcare:** In healthcare, agentic AI can engage with clients, monitor needs, carry out treatment plans, and provide personalized support, enhancing patient care. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Software Development:** Agentic AI can automatically generate debugging code, manage the development lifecycle, and design system architecture, streamlining the software development process. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# - **Cybersecurity:** In cybersecurity, agentic AI can monitor network traffic, detect issues, and respond to threats in real time, enhancing security measures. ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))
#
# **Challenges and Considerations:**
#
# While agentic AI offers numerous advantages, it also presents challenges:
#
# - **Security Risks:** Autonomous AI systems can be vulnerable to hacking or malicious manipulation, potentially leading to harmful decisions in critical sectors. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# - **Unpredictable Behavior:** Without real-time human oversight, agentic AI might exhibit unexpected or undesirable behaviors, especially if their decision-making processes lack transparency. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# - **Ethical and Social Concerns:** Determining responsibility for actions taken by agentic AI can be complex, and there are concerns about potential biases leading to unfair outcomes. ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))
#
# In summary, agentic AI represents a significant advancement in artificial intelligence, enabling systems to operate with a higher degree of independence and adaptability. While it holds the promise of transforming various industries, careful consideration of the associated risks and ethical implications is essential for its responsible deployment.
# [
#     ResponseFunctionWebSearch(
#         id='ws_67e38efce4c88192876b8d05071acf1c0c41044d4989cc3d',
#         status='completed',
#         type='web_search_call'
#     ),
#     ResponseOutputMessage(
#         id='msg_67e38efef5708192b75c0b15ac6121520c41044d4989cc3d',
#         content=[
#             ResponseOutputText(
#                 annotations=[
#                     AnnotationURLCitation(
#                         end_index=484,
#                         start_index=379,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=839,
#                         start_index=751,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1128,
#                         start_index=1023,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1403,
#                         start_index=1298,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1669,
#                         start_index=1564,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=1966,
#                         start_index=1878,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=2225,
#                         start_index=2137,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=2510,
#                         start_index=2422,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=2760,
#                         start_index=2672,
#                         title='What is agentic AI?',
#                         type='url_citation',
#                         url='https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=3140,
#                         start_index=3035,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=3439,
#                         start_index=3334,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     ),
#                     AnnotationURLCitation(
#                         end_index=3730,
#                         start_index=3625,
#                         title='What Is Agentic AI? Complete Guide | TechTarget',
#                         type='url_citation',
#                         url='https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai'
#                     )
#                 ],
#                 text='Agentic AI refers to artificial intelligence systems that possess the capability to act
# autonomously, make decisions, and pursue objectives without continuous human intervention. Unlike traditional AI,
# which typically responds to user inputs or predefined instructions, agentic AI can independently analyze its
# environment, set goals, and execute actions to achieve those goals.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n**Key
# Characteristics of Agentic AI:**\n\n- **Autonomy:** Agentic AI systems can operate independently, reducing the need
# for constant human oversight. This autonomy is particularly beneficial in scenarios that require continuous
# monitoring or rapid decision-making.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n- **Adaptability:**
# These systems can adjust their behavior in response to changes in their environment, allowing them to handle new or
# ambiguous information without human guidance.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n-
# **Problem-Solving:** Agentic AI can engage in planning, reasoning, and goal-setting, enabling them to tackle
# complex tasks beyond the capabilities of traditional AI.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n-
# **Collaboration:** Multiple agentic AI systems can work together to address intricate scenarios, such as
# coordinating efforts in search-and-rescue missions.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n**Pote
# ntial Applications:**\n\n- **Business Operations:** Agentic AI can manage supply chains, optimize inventory levels,
# forecast demand, and plan logistics, leading to increased efficiency and cost savings.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n- **Healthcare:** In
# healthcare, agentic AI can engage with clients, monitor needs, carry out treatment plans, and provide personalized
# support, enhancing patient care.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n- **Software
# Development:** Agentic AI can automatically generate debugging code, manage the development lifecycle, and design
# system architecture, streamlining the software development process.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n- **Cybersecurity:** In
# cybersecurity, agentic AI can monitor network traffic, detect issues, and respond to threats in real time,
# enhancing security measures.
# ([redhat.com](https://www.redhat.com/en/topics/ai/what-is-agentic-ai?utm_source=openai))\n\n**Challenges and
# Considerations:**\n\nWhile agentic AI offers numerous advantages, it also presents challenges:\n\n- **Security
# Risks:** Autonomous AI systems can be vulnerable to hacking or malicious manipulation, potentially leading to
# harmful decisions in critical sectors.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n-
# **Unpredictable Behavior:** Without real-time human oversight, agentic AI might exhibit unexpected or undesirable
# behaviors, especially if their decision-making processes lack transparency.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\n-
# **Ethical and Social Concerns:** Determining responsibility for actions taken by agentic AI can be complex, and
# there are concerns about potential biases leading to unfair outcomes.
# ([techtarget.com](https://www.techtarget.com/searchenterpriseai/definition/agentic-AI?utm_source=openai))\n\nIn
# summary, agentic AI represents a significant advancement in artificial intelligence, enabling systems to operate
# with a higher degree of independence and adaptability. While it holds the promise of transforming various
# industries, careful consideration of the associated risks and ethical implications is essential for its responsible
# deployment. ',
#                 type='output_text'
#             )
#         ],
#         role='assistant',
#         status='completed',
#         type='message'
#     )
# ]
# [
#     WebSearchTool(
#         type='web_search_preview',
#         search_context_size='medium',
#         user_location=UserLocation(
#             type='approximate',
#             city='Lahore',
#             country='PK',
#             region='Punjab',
#             timezone=None
#         )
#     )
# ]
