# %%
# !pip install --quiet --upgrade langchain-text-splitters langchain-community langchain-google-genai  langchain-pinecone

# %%
# !pip install -qU pypdf

# %%
import os
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %%
# Ensure your VertexAI credentials are configured

from langchain_google_genai import ChatGoogleGenerativeAI


llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
embeddings.embed_query("Hello world")
# Out:
# [0.04703257977962494,
#  -0.04019005596637726,
#  -0.02902696467936039,
#  -0.026809632778167725,
#  0.01892058178782463,
#  -8.365760731976479e-05,
#  0.03111639805138111,
#  -0.019520554691553116,
#  0.011491335928440094,
#  0.009625785052776337,
#  0.04571185261011124,
#  0.051709506660699844,
#  -0.007854084484279156,
#  -0.07627559453248978,
#  -0.000736518413759768,
#  -0.022592447698116302,
#  0.011496763676404953,
#  -0.0076109664514660835,
#  0.006400744896382093,
#  -0.0036826308351010084,
#  -8.639021689305082e-05,
#  0.007910552434623241,
#  -0.031401973217725754,
#  -0.027668770402669907,
#  0.013148307800292969,
#  0.005762958899140358,
#  -0.0022430468816310167,
#  -0.07029420882463455,
#  0.007011014502495527,
#  0.07013051956892014,
#  -0.047634560614824295,
#  0.008311820216476917,
#  -0.06021169573068619,
#  0.01643129624426365,
#  0.042709145694971085,
#  -0.047674257308244705,
#  0.0342608243227005,
#  0.021967323496937752,
#  -0.007065100595355034,
#  0.00032590707996860147,
#  0.013825682923197746,
#  -0.08921292424201965,
#  -0.03404068574309349,
#  -0.03793644905090332,
#  0.05934973806142807,
#  -0.004417418036609888,
#  0.015472689643502235,
#  -0.0061533586122095585,
#  0.022183481603860855,
#  -0.08739370852708817,
#  0.049185752868652344,
#  0.025158770382404327,
#  0.044854920357465744,
#  -0.02291061356663704,
#  0.020606976002454758,
#  -0.016286727041006088,
#  0.07367812842130661,
#  0.01356508769094944,
#  -0.06963922083377838,
#  -0.0028775592800229788,
#  0.023692021146416664,
#  0.014378469437360764,
#  -0.012660945765674114,
#  0.06607740372419357,
#  -0.00069232756504789,
#  -0.0176377110183239,
#  -0.06946076452732086,
#  0.04290509968996048,
#  0.035027649253606796,
#  -0.029361996799707413,
#  0.006992147769778967,
#  -0.033415134996175766,
#  0.03652030602097511,
#  -0.039816536009311676,
#  -0.025432651862502098,
#  -0.05665264651179314,
#  -0.010801988653838634,
#  0.04272915795445442,
#  -0.01322994939982891,
#  0.003059837268665433,
#  -0.023508669808506966,
#  -0.06253720819950104,
#  -0.01872997172176838,
#  -0.025751903653144836,
#  -0.09085429459810257,
#  0.03500588610768318,
#  -0.03051295503973961,
#  0.029270736500620842,
#  -0.0024152984842658043,
#  0.07850633561611176,
#  0.010624249465763569,
#  -0.0242887232452631,
#  0.049163106828927994,
#  -0.034781984984874725,
#  -0.033256836235523224,
#  0.04544644057750702,
#  -0.010834701359272003,
#  -0.01698092184960842,
#  0.00034055509604513645,
#  -0.015501156449317932,
#  -0.002625715220347047,
#  0.06123847886919975,
#  -0.00814873818308115,
#  0.007345194928348064,
#  -0.021853728219866753,
#  0.021736575290560722,
#  0.08618097007274628,
#  -0.002957788063213229,
#  -0.01601886935532093,
#  0.008818593807518482,
#  -0.004620355553925037,
#  -0.0006557943415828049,
#  0.034943852573633194,
#  -0.009072228334844112,
#  0.0067808860912919044,
#  -0.017523305490612984,
#  0.0041026100516319275,
#  0.018573487177491188,
#  -0.03208553045988083,
#  -0.04517103731632233,
#  0.03127732500433922,
#  0.012927930802106857,
#  -0.016123343259096146,
#  0.028341401368379593,
#  0.001853146473877132,
#  -0.02286570705473423,
#  0.04789918661117554,
#  0.052842602133750916,
#  0.02135639637708664,
#  0.05655756592750549,
#  -0.0421253927052021,
#  -0.04788326844573021,
#  0.02589700184762478,
#  -0.046798307448625565,
#  0.013322058133780956,
#  -0.048388201743364334,
#  -0.04358474910259247,
#  0.1063060387969017,
#  -0.042358558624982834,
#  0.024962255731225014,
#  0.0030256740283221006,
#  -0.012364417314529419,
#  0.05095597356557846,
#  -0.005733922589570284,
#  0.01313650794327259,
#  -0.002390860579907894,
#  -0.06354273110628128,
#  -0.05458055064082146,
#  -0.004564124159514904,
#  0.023165391758084297,
#  0.06789730489253998,
#  0.0464346669614315,
#  -0.013378120958805084,
#  0.03290952742099762,
#  0.02305278740823269,
#  -0.010280286893248558,
#  -0.009521552361547947,
#  -0.05130810663104057,
#  -0.023044725880026817,
#  -0.01864539459347725,
#  0.08155196905136108,
#  0.03947761654853821,
#  0.00407643336802721,
#  -0.028001654893159866,
#  0.030236272141337395,
#  -0.011227992363274097,
#  0.00878903642296791,
#  -0.043152615427970886,
#  0.02133500948548317,
#  0.01673313044011593,
#  0.01775266043841839,
#  0.00660780118778348,
#  0.004923820961266756,
#  -0.05020229145884514,
#  -0.011205394752323627]

# %%
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone,ServerlessSpec

index_name = "quickstart4"
pc = Pinecone(api_key='pcsk_7BsUSM_Tj1KvA2R5kyyA4F9SPU7KUu7BiDUmWYiYdWJx7aJVCSPkHRYYrDjZcsxyPqhjGh')

pc.create_index(
      name=index_name,
      dimension=768, # Replace with your model dimensions
      metric="cosine", # Replace with your model metric
      spec=ServerlessSpec(
          cloud="aws",
          region="us-east-1"
      )
  )

index = pc.Index(index_name)

vector_store = PineconeVectorStore(embedding=embeddings, index=index)

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load documents
loader = TextLoader("documents.txt")  # Replace with your file
documents = loader.load()

# Split documents into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = text_splitter.split_documents(documents)
print(docs)
# Out:
# [Document(metadata={'source': 'documents.txt'}, page_content='Dr. Eleanor Harper, born on March 3, 1978, in Ashford, England, is a renowned computational linguist and artificial intelligence researcher. She grew up in a small countryside town where her fascination with languages and computers began at an early age. Eleanor was known for her curiosity, often tinkering with her father’s old typewriter and later, the family’s first computer.'), Document(metadata={'source': 'documents.txt'}, page_content='Eleanor graduated with honors in Linguistics from the University of Cambridge in 1999. She later pursued a master’s degree in Computer Science at Stanford University, where her passion for the intersection of language and technology deepened. In 2005, she earned her Ph.D. in Computational Linguistics from the Massachusetts Institute of Technology (MIT), where her groundbreaking thesis focused on machine translation using statistical methods.'), Document(metadata={'source': 'documents.txt'}, page_content='In her professional career, Dr. Harper worked at various leading institutions, including Google Research and the Alan Turing Institute. She led teams that developed state-of-the-art natural language processing algorithms and contributed significantly to open-source AI frameworks.'), Document(metadata={'source': 'documents.txt'}, page_content='Her most notable achievement came in 2015 when she founded LinguaNova AI, a startup aimed at building language models tailored for underrepresented languages. Under her leadership, the company successfully launched “Polyglot AI,” a model capable of translating and generating text in over 150 languages with near-human fluency.'), Document(metadata={'source': 'documents.txt'}, page_content='Apart from her professional achievements, Dr. Harper is a published author, having written three best-selling books on the future of artificial intelligence. Her most popular book, “Language, Machines, and Us,” was translated into 12 languages.'), Document(metadata={'source': 'documents.txt'}, page_content='Eleanor is also an advocate for diversity in tech, actively mentoring young women in STEM fields and speaking at global conferences about ethical AI. In her free time, she enjoys hiking, playing the violin, and exploring ancient manuscripts in libraries worldwide.\n\nDr. Harper currently resides in Zurich, Switzerland, with her two Labrador retrievers, Alpha and Omega. She continues to push the boundaries of AI research while inspiring the next generation of innovators.')]

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.67.1)

# %%
from tqdm import tqdm

# Create embeddings and upload to Pinecone
vectors=[]
for doc in tqdm(docs):
    vector = embeddings.embed_query(doc.page_content)
    # Generate a unique ID for each document (e.g., UUID or hash)
    doc_id = str(hash(doc.page_content))
    # Upsert the vector with a unique ID
    index.upsert(vectors=[(doc_id, vector)])



#
# Out:
# 100%|██████████| 6/6 [00:01<00:00,  3.57it/s]

# %%
from langchain.vectorstores import Pinecone


retriever=  Pinecone(index=index, embedding=embeddings, text_key="text")


# Convert it into a retriever compatible with RetrievalQA
retriever = vector_store.as_retriever()

# %%
from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="refine",  # Other options: "map_reduce", "refine"
    retriever=retriever
)

# %%
query = "Who was Dr. Harper?"
response = qa_chain.run(query)
print(response)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiAttributeError                 Traceback (most recent call last)
# <ipython-input-120-f038f1694112> in <cell line: 2>()
#       1 query = "Who was Dr. Harper?"
# ----> 2 response = qa_chain.run(query)
#       3 print(response)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
#     183
#     184         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     604             if len(args) != 1:
#     605                 raise ValueError("`run` supports only one positional argument.")
# --> 606             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607                 _output_key
#     608             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
#     183
#     184         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     387         }
#     388
# --> 389         return self.invoke(
#     390             inputs,
#     391             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     158             self._validate_inputs(inputs)
#     159             outputs = (
# --> 160                 self._call(inputs, run_manager=run_manager)
#     161                 if new_arg_supported
#     162                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in _call(self, inputs, run_manager)
#     149         )
#     150         if accepts_run_manager:
# --> 151             docs = self._get_docs(question, run_manager=_run_manager)
#     152         else:
#     153             docs = self._get_docs(question)  # type: ignore[call-arg]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/retrieval_qa/base.py in _get_docs(self, question, run_manager)
#     269     ) -> List[Document]:
#     270         """Get docs."""
# --> 271         return self.retriever.invoke(
#     272             question, config={"callbacks": run_manager.get_child()}
#     273         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/retrievers.py in invoke(self, input, config, **kwargs)
#     264         except Exception as e:
#     265             run_manager.on_retriever_error(e)
# --> 266             raise e
#     267         else:
#     268             run_manager.on_retriever_end(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/retrievers.py in invoke(self, input, config, **kwargs)
#     257             _kwargs = kwargs if self._expects_other_args else {}
#     258             if self._new_arg_supported:
# --> 259                 result = self._get_relevant_documents(
#     260                     input, run_manager=run_manager, **_kwargs
#     261                 )
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in _get_relevant_documents(self, query, run_manager, **kwargs)
#    1081         _kwargs = self.search_kwargs | kwargs
#    1082         if self.search_type == "similarity":
# -> 1083             docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1084         elif self.search_type == "similarity_score_threshold":
#    1085             docs_and_similarities = (
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in similarity_search(self, query, k, filter, namespace, **kwargs)
#     377             List of Documents most similar to the query and score for each
#     378         """
# --> 379         docs_and_scores = self.similarity_search_with_score(
#     380             query, k=k, filter=filter, namespace=namespace, **kwargs
#     381         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in similarity_search_with_score(self, query, k, filter, namespace)
#     319             List of Documents most similar to the query and score for each
#     320         """
# --> 321         return self.similarity_search_by_vector_with_score(
#     322             self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     323         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     344         )
#     345         for res in results["matches"]:
# --> 346             metadata = res["metadata"]
#     347             id = res.get("id")
#     348             if self._text_key in metadata:
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/openapi/shared/model_utils.py in __getitem__(self, name)
#     444             return self.get(name)
#     445
# --> 446         raise PineconeApiAttributeError(
#     447             "{0} has no attribute '{1}'".format(type(self).__name__, name), [e for e in [self._path_to_item, name] if e]
#     448         )
#
# PineconeApiAttributeError: ScoredVector has no attribute 'metadata' at ['['received_data', 'matches', 0]']['metadata']
